# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
from sklearn.datasets import load_boston, load_iris

# %%
df = pd.read_csv("data/malicious_01.csv")

# %%
df.head()
# Out:
#   INCIDENT_ID       DATE  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  X_10  \
# 0   CR_102659  04-JUL-04    0   36   34    2    1    5    6    1    6     1
# 1   CR_189752  18-JUL-17    1   37   37    0    0   11   17    1    6     1
# 2   CR_184637  15-MAR-17    0    3    2    3    5    1    0    2    3     1
# 3   CR_139071  13-FEB-09    0   33   32    2    1    7    1    1    6     1
# 4   CR_109335  13-APR-05    0   33   32    2    1    8    3    0    5     1
#
#    X_11  X_12  X_13  X_14  X_15  MALICIOUS_OFFENSE
# 0   174   1.0    92    29    36                  0
# 1   236   1.0   103   142    34                  1
# 2   174   1.0   110    93    34                  1
# 3   249   1.0    72    29    34                  1
# 4   174   0.0   112    29    43                  1

# %%
# X , Y = df['X_1'], df["MALICIOUS_OFFENSE"]
 

offense = df["MALICIOUS_OFFENSE"]==1
len(df)
len(df[offense])

# X =df[["X_1","X_2"]].values
# plt.scatter(X[:,0], X[:,1],  c=offense),
X =df[["X_5","X_2"]].values
plt.scatter(X[:,0], X[:,1],  c=offense),
# Out:
# (<matplotlib.collections.PathCollection at 0x136ed1820>,)

# %%
plt.figure(figsize=(12,10))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
cor_target = abs(cor["MALICIOUS_OFFENSE"])
high_featues = cor_target[cor_target > 0.5]
high_featues
# Out:
# MALICIOUS_OFFENSE    1.0
# Name: MALICIOUS_OFFENSE, dtype: float64

# %%
iris_data = load_iris()
print(iris_data['DESCR'])
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...
